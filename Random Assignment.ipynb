# %%
import numpy as np
import random

# %%
GTAs = ['Mike','Danielle','Xinyi']
Team_nums = list(range(18))
Number_to_assign = int(len(Team_nums)/len(GTAs))
for i in GTAs:
    Assignment_i = random.sample(Team_nums, Number_to_assign)
    for j in Assignment_i:
        Team_nums.remove(j)
    
    print(i )
    print(Assignment_i)
# Out:
# Mike
# [9, 14, 4, 7, 1, 5]
# Danielle
# [17, 6, 15, 3, 0, 8]
# Xinyi
# [13, 10, 11, 16, 12, 2]

# %%
# Out:
# 6
